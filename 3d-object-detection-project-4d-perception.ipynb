# %% [markdown]
# # Welcome to the 3D Object Detection & Visualization Workshop!
# In this notebook, you'll work with a sequence of images and point clouds, and will learn to run 3D object detection algorithms to them. We will also learn how to visualize our results in 2D and 3D environments. So let us begin.
# <p>
#
# **Note:** This notebook has been adapted for educational purpose from [this repo](https://github.com/hailanyi/3D-Detection-Tracking-Viewer), and the model is running with weights downloaded on [this repo](https://github.com/open-mmlab/OpenPCDet).

# %%
#!pip install spconv-cu118 -q
#!pip install SharedArray2 -q
#!pip install ipyvtklink -q
#!pip install pyquaternion==0.9.9

# %%
#!pip install rerun-sdk==0.22.1

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: ipykernel in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (7.3.0)
# Requirement already satisfied: tqdm in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (4.68.2)
# Requirement already satisfied: easydict in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.13)
# Requirement already satisfied: opencv-python in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (4.11.0.86)
# Requirement already satisfied: scipy in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.14.1)
# Requirement already satisfied: scikit-image in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.24.0)
# Requirement already satisfied: torch==1.13.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (1.13.1)
# Requirement already satisfied: torchvision in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.14.1)
# Requirement already satisfied: torchaudio in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (2.11.0)
# Requirement already satisfied: matplotlib in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (3.10.9)
# Requirement already satisfied: pyquaternion==0.9.9 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (0.9.9)
# Requirement already satisfied: spconv-cu118 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (2.3.8)
# Requirement already satisfied: SharedArray2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (3.2.5)
# Requirement already satisfied: ipyvtklink in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (0.2.3)
# Requirement already satisfied: rerun-sdk==0.22.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (0.22.1)
# Requirement already satisfied: open3d in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (0.16.0)
# Requirement already satisfied: numpy==1.23.5 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (1.23.5)
# Requirement already satisfied: typing-extensions in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from torch==1.13.1->-r requirements.txt (line 11)) (4.15.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from torch==1.13.1->-r requirements.txt (line 11)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from torch==1.13.1->-r requirements.txt (line 11)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from torch==1.13.1->-r requirements.txt (line 11)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from torch==1.13.1->-r requirements.txt (line 11)) (11.7.99)
# Requirement already satisfied: attrs>=23.1.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from rerun-sdk==0.22.1->-r requirements.txt (line 19)) (26.1.0)
# Requirement already satisfied: pillow>=8.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from rerun-sdk==0.22.1->-r requirements.txt (line 19)) (12.2.0)
# Requirement already satisfied: pyarrow>=14.0.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from rerun-sdk==0.22.1->-r requirements.txt (line 19)) (24.0.0)
# Requirement already satisfied: setuptools in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements.txt (line 11)) (65.5.0)
# Requirement already satisfied: wheel in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r requirements.txt (line 11)) (0.47.0)
# Requirement already satisfied: rerun-notebook==0.22.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from rerun-sdk[notebook]==0.22.1->-r requirements.txt (line 23)) (0.22.1)
# Requirement already satisfied: anywidget in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from rerun-notebook==0.22.1->rerun-sdk[notebook]==0.22.1->-r requirements.txt (line 23)) (0.11.0)
# Requirement already satisfied: jupyter-ui-poll in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from rerun-notebook==0.22.1->rerun-sdk[notebook]==0.22.1->-r requirements.txt (line 23)) (1.1.0)
# Requirement already satisfied: comm>=0.1.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (8.39.0)
# Requirement already satisfied: jupyter-client>=8.9.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (1.7.2)
# Requirement already satisfied: packaging>=22 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (26.2)
# Requirement already satisfied: psutil>=5.7 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (6.5.7)
# Requirement already satisfied: traitlets>=5.4.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipykernel->-r requirements.txt (line 5)) (5.15.1)
# Requirement already satisfied: networkx>=2.8 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 10)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 10)) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from scikit-image->-r requirements.txt (line 10)) (0.5)
# Requirement already satisfied: requests in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from torchvision->-r requirements.txt (line 12)) (2.34.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 14)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 14)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 14)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 14)) (2.9.0.post0)
# Requirement already satisfied: pccm>=0.4.16 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from spconv-cu118->-r requirements.txt (line 16)) (0.4.16)
# Requirement already satisfied: ccimport>=0.4.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from spconv-cu118->-r requirements.txt (line 16)) (0.4.4)
# Requirement already satisfied: pybind11>=2.6.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from spconv-cu118->-r requirements.txt (line 16)) (3.0.4)
# Requirement already satisfied: fire in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from spconv-cu118->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: cumm-cu118<0.8.0,>=0.7.11 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from spconv-cu118->-r requirements.txt (line 16)) (0.7.11)
# Requirement already satisfied: sympy in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from cumm-cu118<0.8.0,>=0.7.11->spconv-cu118->-r requirements.txt (line 16)) (1.14.0)
# Requirement already satisfied: ipycanvas>=0.5.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipyvtklink->-r requirements.txt (line 18)) (0.14.3)
# Requirement already satisfied: ipyevents>=0.8.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipyvtklink->-r requirements.txt (line 18)) (2.0.4)
# Requirement already satisfied: ipywidgets~=7.7 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipyvtklink->-r requirements.txt (line 18)) (7.8.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.10 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.1.11)
# Requirement already satisfied: notebook>=4.4.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (7.5.7)
# Requirement already satisfied: dash>=2.6.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from open3d->-r requirements.txt (line 22)) (4.3.0)
# Requirement already satisfied: nbformat==5.5.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from open3d->-r requirements.txt (line 22)) (5.5.0)
# Requirement already satisfied: configargparse in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from open3d->-r requirements.txt (line 22)) (1.7.5)
# Requirement already satisfied: addict in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from open3d->-r requirements.txt (line 22)) (2.4.0)
# Requirement already satisfied: pandas>=1.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from open3d->-r requirements.txt (line 22)) (2.3.3)
# Requirement already satisfied: pyyaml>=5.4.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from open3d->-r requirements.txt (line 22)) (6.0.3)
# Requirement already satisfied: scikit-learn>=0.21 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from open3d->-r requirements.txt (line 22)) (1.7.2)
# Requirement already satisfied: fastjsonschema in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbformat==5.5.0->open3d->-r requirements.txt (line 22)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbformat==5.5.0->open3d->-r requirements.txt (line 22)) (4.26.0)
# Requirement already satisfied: ninja in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ccimport>=0.4.4->spconv-cu118->-r requirements.txt (line 16)) (1.13.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (3.1.3)
# Requirement already satisfied: Werkzeug<3.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (3.1.8)
# Requirement already satisfied: plotly>=5.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (6.8.0)
# Requirement already satisfied: importlib-metadata in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (9.0.0)
# Requirement already satisfied: retrying in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (1.4.2)
# Requirement already satisfied: nest-asyncio in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (1.6.0)
# Requirement already satisfied: janus>=1.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.0.0)
# Requirement already satisfied: pydantic>=2.10 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.13.4)
# Requirement already satisfied: mcp>=1.23.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from dash>=2.6.0->open3d->-r requirements.txt (line 22)) (1.28.0)
# Requirement already satisfied: blinker>=1.9.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (8.4.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from Flask<3.2,>=1.0.4->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (3.0.3)
# Requirement already satisfied: decorator in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (5.3.1)
# Requirement already satisfied: exceptiongroup in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: pexpect>4.3 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (2.20.0)
# Requirement already satisfied: stack_data in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (0.8.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.5.0->open3d->-r requirements.txt (line 22)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.5.0->open3d->-r requirements.txt (line 22)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.5.0->open3d->-r requirements.txt (line 22)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r requirements.txt (line 5)) (4.10.0)
# Requirement already satisfied: anyio>=4.5 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (4.14.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.14.2)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (0.0.32)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (0.49.0)
# Requirement already satisfied: certifi in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from httpx<1.0.0,>=0.27.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from httpx<1.0.0,>=0.27.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (1.0.9)
# Requirement already satisfied: idna in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from httpx<1.0.0,>=0.27.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pydantic>=2.10->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pydantic>=2.10->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.46.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.19.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.8 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (4.5.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.2.4)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (7.4.0)
# Requirement already satisfied: overrides>=5.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyterlab<4.6,>=4.5.8->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.3.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyterlab<4.6,>=4.5.8->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.3.1)
# Requirement already satisfied: tomli>=1.2.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyterlab<4.6,>=4.5.8->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.4.1)
# Requirement already satisfied: babel>=2.10 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.14.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.1.1)
# Requirement already satisfied: fqdn in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.5.1)
# Requirement already satisfied: isoduration in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.1.0)
# Requirement already satisfied: uri-template in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (4.15.0)
# Requirement already satisfied: bleach in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (6.4.0)
# Requirement already satisfied: defusedxml in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.3.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pandas>=1.0->open3d->-r requirements.txt (line 22)) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pandas>=1.0->open3d->-r requirements.txt (line 22)) (2026.2)
# Requirement already satisfied: lark>=1.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pccm>=0.4.16->spconv-cu118->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: portalocker>=2.3.2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pccm>=0.4.16->spconv-cu118->-r requirements.txt (line 16)) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.22.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (2.0.0)
# Requirement already satisfied: pycparser in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.23.0->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (3.0)
# Requirement already satisfied: six>=1.5 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 14)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from requests->torchvision->-r requirements.txt (line 12)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from requests->torchvision->-r requirements.txt (line 12)) (2.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d->-r requirements.txt (line 22)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d->-r requirements.txt (line 22)) (3.6.0)
# Requirement already satisfied: psygnal>=0.8.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from anywidget->rerun-notebook==0.22.1->rerun-sdk[notebook]==0.22.1->-r requirements.txt (line 23)) (0.15.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (2.8.4)
# Requirement already satisfied: webencodings in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: termcolor in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from fire->spconv-cu118->-r requirements.txt (line 16)) (3.3.0)
# Requirement already satisfied: zipp>=3.20 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from importlib-metadata->dash>=2.6.0->open3d->-r requirements.txt (line 22)) (4.1.0)
# Requirement already satisfied: arrow>=0.15.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.10->ipywidgets~=7.7->ipyvtklink->-r requirements.txt (line 18)) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: pure-eval in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/brian/miniconda3/envs/4D/lib/python3.10/site-packages (from sympy->cumm-cu118<0.8.0,>=0.7.11->spconv-cu118->-r requirements.txt (line 16)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Imports

# %%
# now run 
import os
import sys
sys.path.append("/home/brian/code/4D-Perception/kaggle/input/4d-dataset/")
sys.path.append("/home/brian/code/4D-Perception/kaggle/input/4d-dataset/multi_object_tracking/multi_object_tracking")
sys.path.append("/home/brian/code/4D-Perception/kaggle/input/4d-dataset/viewer")
sys.path.append("/home/brian/code/4D-Perception/kaggle/input/4d-dataset/pointrcnn/pointrcnn")
sys.path.append("/home/brian/code/4D-Perception/kaggle/input/4d-dataset/pointrcnn/pointrcnn/pcdet")

# %%
import time
import tqdm
import logging
import argparse
from pathlib import Path
import yaml
import json
from easydict import EasyDict
from collections.abc import Sequence
from dataclasses import dataclass
from typing import Any, Final
import glob
from tqdm import tqdm
import cv2
import shutil
import requests
import re
from PIL import Image
from scipy.spatial.transform import Rotation as R
from IPython.display import FileLink, display

# %%
import numpy as np
import numpy.typing as npt
import torch
import rerun as rr
import matplotlib.pyplot as plt
import rerun.blueprint as rrb  
from scipy.spatial.transform import Rotation as R

# %%
from dataset.kitti_data_base import velo_to_cam
from dataset.kitti_data_base import *  # verify this is necessary
from utils import *                    # utils du viewer

# %%
from pcdet.ops.roiaware_pool3d import roiaware_pool3d_cuda
from pcdet.config import cfg, cfg_from_yaml_file
from pcdet.datasets import DatasetTemplate
from pcdet.utils import common_utils
from pcdet.utils.box_utils import project_3d_box_to_image
from box_3d import Box3D
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from pcdet.ops.roiaware_pool3d import roiaware_pool3d_cuda
#       2 from pcdet.config import cfg, cfg_from_yaml_file
#       3 from pcdet.datasets import DatasetTemplate
#
# ImportError: /home/brian/code/4D-Perception/kaggle/input/4d-dataset/pointrcnn/pointrcnn/pcdet/ops/roiaware_pool3d/roiaware_pool3d_cuda.cpython-310-x86_64-linux-gnu.so: undefined symbol: _ZN3c106detail19maybe_wrap_dim_slowIlEET_S2_S2_b

# %% [markdown]
# ## 2. Data

# %%
class KittiDataset(DatasetTemplate):
    def __init__(self,root_path,seq_id, dataset_cfg, class_names, label_path = None):
        super().__init__(
            dataset_cfg=dataset_cfg, class_names=class_names, training=False, root_path=root_path
        )
        self.seq_name = str(seq_id).zfill(4)
        self.root_path = root_path
        self.velo_path = os.path.join(self.root_path,"velodyne", self.seq_name)
        self.image_path = os.path.join(self.root_path,"image_02", self.seq_name)
        self.calib_path = os.path.join(self.root_path,"calib")
        self.label_path = label_path
        pose_path = os.path.join(self.root_path, "pose", self.seq_name,'pose.txt')
        self.poses = read_pose(pose_path)

    def __len__(self):
        return len(os.listdir(self.velo_path))

    def __getitem__(self, item):
        input_dict = {}
        name = str(item).zfill(6)
        velo_path = os.path.join(self.velo_path,name+'.bin')
        image_path = os.path.join(self.image_path, name+'.png')
        calib_path = os.path.join(self.calib_path, self.seq_name+'.txt')

        input_dict["frame_id"] = item

        pose = self.poses[item] if item in self.poses.keys() else None;
        input_dict["pose"] = pose

        P2,V2C = read_calib(calib_path)
        input_dict["P2"] = P2
        input_dict["V2C"] = V2C

        points = read_velodyne(velo_path,P2,V2C)
        input_dict["points"] = points

        image = read_image(image_path)
        input_dict["image"] = image

        objects, objects_cam, det_scores, det_names = [], [], [], []

        if self.label_path is not None:
            # If we have a label path, we'll read the labels instead of predicting them
            label_path = os.path.join(self.label_path, self.seq_name, name+'.txt')
            objects, det_scores, det_names = self.read_detection_label(label_path)
        if len(objects)>0:
            objects_cam = np.copy(objects)
            objects[:,3:6] = cam_to_velo(objects[:,3:6],V2C)[:,:3]
        input_dict["objects"] = objects
        input_dict["objects_cam"] = objects_cam
        input_dict["scores"] = det_scores
        input_dict["names"] = det_names

        return input_dict

    def read_detection_label(self,label_path):
        objects_list = []
        det_scores = []
        det_names = []
        with open(label_path) as f:
            for each_ob in f.readlines():
                infos = re.split(' ', each_ob)
                if infos[0] in ['Car', 'Truck','Van', 'Cyclist']:
                    objects_list.append(infos[8:15])
                    det_scores.append(infos[15])
                    det_names.append(infos[0])
        return np.array(objects_list, np.float32), np.array(det_scores, np.float32), det_names

# %%
cfg_file = '/home/brian/code/4D-Perception/kaggle/input/4d-dataset/pointrcnn/pointrcnn/pointrcnn.yaml'## this further uses kitti_dataset.yaml

# %%
cfg_from_yaml_file(cfg_file, cfg)

# %%
cfg.CLASS_NAMES

# %%
root="/home/brian/code/4D-Perception/kaggle/input/4d-dataset/data/data"
label_dir = "/home/brian/code/4D-Perception/kaggle/input/4d-dataset/multi_object_tracking/multi_object_tracking/detectors/second_iou"

dataset = KittiDataset(root,seq_id=8,label_path=label_dir,
                       dataset_cfg = cfg.DATA_CONFIG, class_names = cfg.CLASS_NAMES)

# %%
def view_images(images_to_be_shown):
  _, axs = plt.subplots(1, len(images_to_be_shown), figsize=(30, 30))

  if len(images_to_be_shown)> 1:
    axs = axs.flatten()
    for img, ax in zip(images_to_be_shown, axs):
        ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
  else:
        axs.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
      
  plt.show()


hand_picked_frames = [0,1,2,3]
images_2d = [dataset[i]["image"] for i in hand_picked_frames]

view_images(images_2d)

# %% [markdown]
# ## 3. Data & Label Visualization (3D Viewer)

# %%
def visualize(dataset, frames=None, output_path=None,score_threshold=0.8, viz_labels=False):
    rr.init("KITTI Visualizer", recording_id="new_run", spawn=False)

    blueprint = rrb.Blueprint(
        rrb.Horizontal(
            rrb.Spatial2DView(origin="world/ego_vehicle/camera", name="Camera"),
            rrb.Spatial3DView(origin="world/ego_vehicle/lidar", name="LiDAR"),
            column_shares=[1, 1]
        )
    )

    rr.log("world/ego_vehicle/camera/", rr.ViewCoordinates.RIGHT_HAND_Y_DOWN)
    rr.log("world/ego_vehicle/lidar/", rr.ViewCoordinates.RIGHT_HAND_Z_UP)

    class_colors = {
        'Car': [255, 0, 0, 128],
        'Pedestrian': [0, 255, 0, 128],
        'Cyclist': [0, 0, 255, 128]
    }

    if frames is None:
        frames = list(range(len(dataset)))

    for i in frames:
        rr.set_time_sequence("frame", i)
        rr.log("world/ego_vehicle/camera/image/detections", rr.Clear(recursive=True))
        rr.log("world/ego_vehicle/lidar/boxes", rr.Clear(recursive=True))

        data = dataset[i]
        image = np.array(data['image'])
        points = data['points']
        P2, V2C = data['P2'], data['V2C']
        pose = data['pose']

        if pose is not None:  
            # Extract translation and rotation from pose matrix  
            translation = pose[:3, 3]  # Extract translation from 4x4 pose matrix  
            rotation_matrix = pose[:3, :3]  # Extract rotation matrix  
            # Convert rotation matrix to quaternion  
            r = R.from_matrix(rotation_matrix)  
            quat_xyzw = r.as_quat()  # scipy returns [x, y, z, w]  
              
            rr.log("world/ego_vehicle", rr.Transform3D(  
                translation=translation,  
                quaternion=rr.Quaternion(xyzw=quat_xyzw),  
                relation=rr.TransformRelation.ParentFromChild,  
            )) 
        
        rr.log("world/ego_vehicle/camera/image", rr.Image(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)))
        
        positions = points[:, :3]
        distances = np.linalg.norm(positions, axis=1)
        norm = (255.0 * (distances - distances.min()) / (np.ptp(distances) + 1e-5)).astype(np.uint8)
        colors = (plt.cm.cividis(norm / 255.0)[:, :3] * 255).astype(np.uint8)
        rr.log("world/ego_vehicle/lidar/points", rr.Points3D(positions=positions, colors=colors))

        if viz_labels:
            centers, sizes, rotations, labels, box_colors = [], [], [], [], []
    
            for j, (box, box_cam, score, name) in enumerate(zip(data['objects'], data['objects_cam'], data['scores'], data['names'])):
                if score < score_threshold:
                    continue
    
                # 3D Camera Boxes
                corners_2d = project_3d_box_to_image(box_cam,P2)
                edges = [
                    [0, 1], [1, 2], [2, 3], [3, 0],
                    [4, 5], [5, 6], [6, 7], [7, 4],
                    [0, 4], [1, 5], [2, 6], [3, 7]
                ]
                lines = [np.array([corners_2d[start], corners_2d[end]]) for start, end in edges]
                box_colors.append(class_colors.get(name, [128, 128, 128, 128]))
    
                rr.log(f"world/ego_vehicle/camera/image/detections/box_{j}", rr.LineStrips2D(lines, labels=[f"{name} {score:.2f}"], colors=np.array(box_colors)))
                rr.log(f"world/ego_vehicle/camera/image/detections/box_{j}/label", rr.Points2D([np.mean(corners_2d, axis=0)], colors=np.array(box_colors)))
                
    
                # 3D Lidar boxes 
                h, w, l, x, y, z, ry = box  
                # Convert KITTI rotation to Rerun coordinate system  
                yaw = -ry - np.pi / 2  
                center = np.array([x, y, z + h / 2])  
                size = np.array([l, w, h])  
  
                # Create quaternion for rotation around Z-axis in Rerun's coordinate system  
                quat = R.from_euler('z', yaw, degrees=False).as_quat()  
                # Rerun expects [w, x, y, z] format  
                quat = np.array([quat[0], quat[1], quat[2], quat[3]])
    
                centers.append(center)
                sizes.append(size)
                rotations.append(quat)
                labels.append(f"{name} {score:.2f}")
    
            if centers:
                rr.log("world/ego_vehicle/lidar/boxes", rr.Boxes3D(
                    centers=np.array(centers),
                    half_sizes=np.array(sizes) / 2,
                    quaternions=np.array(rotations),
                    labels=labels,
                    colors=np.array(box_colors),
                    fill_mode="solid"
                ))

    rr.save(output_path, default_blueprint=blueprint)
    print(f"Visualization saved. Run:\nrerun {output_path}")

# %%
out_path = "./kaggle/working/data.rrd"
visualize(dataset, output_path=out_path, frames=range(220,270), viz_labels=False)

### If your code breaks, the rerun will break. Make
#rr.save("test.rrd")

# %% [markdown]
# Try to visualize One Frame, then some Hand Picked Frames, then the entire video!

# %% [markdown]
# ### Label Visualization

# %% [markdown]
# ![img](https://thinkautonomous-3d-tracking.s3.us-west-2.amazonaws.com/download+(1)+(1).jpeg)

# %%
out_path = "./kaggle/working/labels55.rrd"
visualize(dataset, output_path = out_path, frames=range(200,300), viz_labels=True)

### If your code breaks, the rerun will break. Make
#rr.save("test.rrd")

# %% [markdown]
# ## 4. 3D Object Detection
# Later in the course, we'll work with Object Trackers. There are 2 types of trackers:
# 1.   **Separate Trackers**
# 2.   **Joint Trackers**
#
# The first type first detect objects and then track them (using algorithms we explore in the course). The second type directly outputs tracking based on a sequence (2 images or files sent to a neural network, a tracking input).
#
# In this notebook, we'll use the **first type**. And therefore our first task will be to detect the objects.
# <p>
#
# In this notebook, we'll focus on tracking and therefore run this as black box. You'll still be able to understand how this works, play with the point clouds, inputs and outputs. If you'd like more details on the inside of this architecture, I refer you to my course [DEEP POINT CLOUDS](https://courses.thinkautonomous.ai/deep-point-clouds).
# <p>

# %% [markdown]
# ![](https://raw.githubusercontent.com/sshaoshuai/PointRCNN/master/doc/teaser.png)

# %% [markdown]
# #### PointRCNN
# We'll use the library OpenPCDet, which will implement the PointRCNN algorithm based on [this repo](https://github.com/open-mmlab/OpenPCDet).<p>

# %%
from pcdet.models import build_network, load_data_to_gpu

# %%
import argparse
import glob
from pathlib import Path
import torch

# %%
from box_3d import *

# %%
model_ckpt = '/home/brian/code/4D-Perception/kaggle/input/4d-dataset/pointrcnn/pointrcnn/pointrcnn_7870.pth'

output_file_dir = f'./kaggle/working/3d_object_detection_results/0008'
id_to_name = {1: 'Car', 2: 'Pedestrian', 3: 'Cyclist', 4: 'Van'}

# %%
print(cfg.CLASS_NAMES)

# %%
logger = common_utils.create_logger()
logger.info(f"CLASS_NAMES: {cfg.CLASS_NAMES}")

# %%
model = build_network(model_cfg=cfg.MODEL, num_class=len(cfg.CLASS_NAMES), dataset=dataset)
model.load_params_from_file(filename=model_ckpt,logger=logger, to_cpu=True)
model.cuda()

# %%
# !mkdir -p './kaggle/working/3d_object_detection_results/0008'

# %%
def limit_period(val, offset=0.5, period=np.pi):
    """Limit the value into a period for periodic function.
    Args:
        val (torch.Tensor | np.ndarray): The value to be converted.
        offset (float, optional): Offset to set the value range.
            Defaults to 0.5.
        period ([type], optional): Period of the value. Defaults to np.pi.
    Returns:
        (torch.Tensor | np.ndarray): Value in the range of
            [-offset * period, (1-offset) * period]
    """
    limited_val = val - np.floor(val / period + offset) * period
    return limited_val

# %%
print(len(dataset))

# %%
hand_picked_frames = range(len(dataset))
print(len(hand_picked_frames))

# %%
model.eval()
with torch.no_grad():
  for i in hand_picked_frames:
      print(i)
      inference_result = []
      #read data
      data_dict = {k: dataset[i][k] for k in ["points","frame_id"] if k in dataset[i]}
      data_dict = dataset.collate_batch([data_dict])
      load_data_to_gpu(data_dict)

      #Forward propagation
      pred_dicts, _ = model.forward(data_dict)
      points=data_dict['points']#[:, :3]
      bboxes=pred_dicts[0]['pred_boxes'].cpu().detach().numpy()
      scores=pred_dicts[0]['pred_scores'].cpu().detach().numpy()
      labels=pred_dicts[0]['pred_labels'].cpu().detach().numpy()
      P2 = np.column_stack((dataset[i]["P2"].T, [0,0,1,0]))

      #Postprocess
      inference_result.append([])
      for bbox, score, label in zip(bboxes, scores, labels):
          pos = bbox[:3]  # x, y, z
          dim = bbox[[4, 5, 3]]   # w, h, l
          yaw = bbox[-1]
          yaw = -yaw - np.pi / 2
          yaw = limit_period(yaw, period=np.pi * 2)
          label_name = id_to_name[label]
          box3d = Box3D(pos, dim, yaw, label_name, score, dataset[i]["V2C"].T, P2)
          inference_result[-1].append(box3d)
      #Write to file
      output_file_name = output_file_dir + '/' + str(i).zfill(6) + '.txt'
      f = open(output_file_name, 'w+')
      for each_3d_box in inference_result[0]:
          f.write(each_3d_box.to_kitti_format(each_3d_box.confidence))
          f.write('\n')
      f.close()

# %%
print(bboxes)
print(scores)
print(labels)

# %%
label_path = "/kaggle/working/3d_object_detection_results"
output_path = "/kaggle/working/pointrcnn.rrd"

dataset = KittiDataset(root,seq_id = 8, label_path=label_path, dataset_cfg=cfg.DATA_CONFIG, class_names=cfg.CLASS_NAMES)

visualize(dataset, output_path = output_path, frames=hand_picked_frames, viz_labels=True)

# %% [markdown]
# ### 3.2. Try another model

# %%
#cfg_file = '/kaggle/input/4d-perception-second/second.yaml'
cfg_file = '/kaggle/input/4d-perception-second/PartA2_free.yaml'

cfg_from_yaml_file(cfg_file, cfg)

logger = common_utils.create_logger()

from pcdet.datasets import build_dataloader
dataset, dataloader, _ = build_dataloader(
    dataset_cfg=cfg.DATA_CONFIG,
    class_names=cfg.CLASS_NAMES,
    batch_size=1,
    dist=False,
    workers=0,
    logger=logger,
    training=False
)

#model_ckpt = '/kaggle/input/4d-perception-second/second_7862.pth'
model_ckpt = '/kaggle/input/4d-perception-second/PartA2_free_7872.pth'

from pcdet.models import build_network
model = build_network(model_cfg=cfg.MODEL, num_class=len(cfg.CLASS_NAMES), dataset=dataset)
model.load_params_from_file(filename=model_ckpt, logger=logger, to_cpu=False)
model.cuda()
model.eval()

data_dict = dataset[0]
from pcdet.datasets.collate_utils import collate_batch
from pcdet.utils.common_utils import move_data_to_device

batch = collate_batch([data_dict])
move_data_to_device(batch, device=torch.device("cuda"))
preds, _ = model(batch)

# %% [markdown]
# ## 5. Visualize Tracking

# %%
from dataset.kitti_data_base import read_tracking_label

# %%
def visualize_tracking(dataset, tracking_label_path, frames=None, output_path=None, score_threshold=0.8):  
    rr.init("KITTI Tracking Visualizer", recording_id="tracking_run", spawn=False)  
      
    blueprint = rrb.Blueprint(  
        rrb.Spatial3DView(origin="world/ego_vehicle/lidar", name="LiDAR Tracking")  
    )  
      
    # Set coordinate system for LiDAR space  
    rr.log("world/ego_vehicle/lidar/", rr.ViewCoordinates.RIGHT_HAND_Z_UP)  
      
    # Load tracking data  
    tracking_frame_dict, tracking_names_dict = read_tracking_label(tracking_label_path)  
      
    if frames is None:  
        frames = list(range(len(dataset)))  
      
    # Store trajectories for visualization  
    trajectories = {}  # track_id -> list of center_3d positions  
      
    for i in frames:  
        rr.set_time_sequence("frame", i)  
        rr.log("world/ego_vehicle/lidar/boxes", rr.Clear(recursive=True))  
        rr.log("world/ego_vehicle/lidar/trajectories", rr.Clear(recursive=True))  
          
        data = dataset[i]  
        points = data['points']  
        pose = data['pose']  
  
        if pose is not None:  
            # Extract translation and rotation from pose matrix  
            translation = pose[:3, 3]  # Extract translation from 4x4 pose matrix  
            rotation_matrix = pose[:3, :3]  # Extract rotation matrix  
            # Convert rotation matrix to quaternion  
            r = R.from_matrix(rotation_matrix)  
            quat_xyzw = r.as_quat()  # scipy returns [x, y, z, w]  
              
            rr.log("world/ego_vehicle", rr.Transform3D(  
                translation=translation,  
                quaternion=rr.Quaternion(xyzw=quat_xyzw),  
                relation=rr.TransformRelation.ParentFromChild,  
            ))  
          
        # Log point cloud with distance-based coloring  
        positions = points[:, :3]  
        distances = np.linalg.norm(positions, axis=1)  
        norm = (255.0 * (distances - distances.min()) / (np.ptp(distances) + 1e-5)).astype(np.uint8)  
        colors = (plt.cm.cividis(norm / 255.0)[:, :3] * 255).astype(np.uint8)  
        rr.log("world/ego_vehicle/lidar/points", rr.Points3D(positions=positions, colors=colors))  
          
        if i not in tracking_frame_dict:  
            continue  
          
        track_data = tracking_frame_dict[i]  
        track_names = tracking_names_dict[i]  
          
        centers, sizes, rotations, labels, colors = [], [], [], [], []  
          
        for entry, name in zip(track_data, track_names):  
            h, w, l, x, y, z, ry, track_id = entry  
              
            if l * w * h == 0:  # Skip invalid boxes  
                continue  
              
            # KITTI coordinate system: X=right, Y=down, Z=forward  
            # Rerun RIGHT_HAND_Z_UP: X=right, Y=forward, Z=up  
            center = np.array([z, -x, -y + h / 2])  # Transform KITTI to Rerun coordinates  
            size = np.array([l, w, h])    
              
            # Fix rotation: Ensure boxes are horizontal and properly oriented  
            # For horizontal boxes in the XY plane, we need to adjust the rotation  
            yaw = -ry + np.pi / 2  # Adjust rotation to keep boxes horizontal  
            quat = R.from_euler('z', yaw, degrees=False).as_quat()  
            quat_rerun = np.array([quat[3], quat[0], quat[1], quat[2]])  # [w,x,y,z]  
              
            # Generate unique color per track ID  
            color = np.array([  
                (37 * track_id) % 255,  
                (17 * track_id) % 255,  
                (91 * track_id) % 255,  
                255  
            ]).astype(np.uint8)  
              
            centers.append(center)  
            sizes.append(size)  
            rotations.append(quat_rerun)  
            labels.append(f"ID {int(track_id)}")  
            colors.append(color)  
              
            # Store trajectory data with corrected coordinates  
            if track_id not in trajectories:  
                trajectories[track_id] = []  
            trajectories[track_id].append(center.copy())  
          
        # Log 3D boxes  
        if centers:  
            rr.log("world/ego_vehicle/lidar/boxes", rr.Boxes3D(  
                centers=np.array(centers),  
                half_sizes=np.array(sizes) / 2,  
                quaternions=np.array(rotations),  
                labels=labels,  
                colors=np.array(colors),  
                fill_mode="solid"  
            ))  
          
        # Log trajectories with unique colors per track  
        for track_id, trajectory in trajectories.items():  
            if len(trajectory) > 1:  
                # Only show trajectory up to current frame  
                current_frame_trajectory = trajectory[:len([f for f in frames if f <= i])]  
                if len(current_frame_trajectory) > 1:  
                    trajectory_points = np.array(current_frame_trajectory)  
                      
                    # Generate the same unique color for this track ID as used for boxes  
                    trajectory_color = np.array([  
                        (37 * track_id) % 255,  
                        (17 * track_id) % 255,  
                        (91 * track_id) % 255,  
                        180  # Alpha for transparency  
                    ]).astype(np.uint8)  
                      
                    # Create trajectory line with unique color  
                    rr.log(  
                        f"world/ego_vehicle/lidar/trajectories/track_{track_id}",  
                        rr.LineStrips3D([trajectory_points], colors=[trajectory_color])  
                    )  
                      
                    # Mark trajectory points with the same color  
                    rr.log(  
                        f"world/ego_vehicle/lidar/trajectories/track_{track_id}/points",  
                        rr.Points3D(trajectory_points, colors=[trajectory_color], radii=[0.1])  
                    )  
      
    rr.save(output_path, default_blueprint=blueprint)  
    print(f"Tracking visualization saved. Run:\nrerun {output_path}")

# %%
#  Add the tracking path
preds_path = "/kaggle/working/3d_object_detection_results"
tracking_path = "/home/brian/code/4D-Perception/kaggle/input/4d-dataset/0008/0008.txt"
out_path_pred = "/kaggle/working/predictions_video_sequence11.rrd"
visualize_tracking(  
    dataset=dataset,  
    tracking_label_path=tracking_path,  
    frames=hand_picked_frames,  # First 30 frames  
    output_path=out_path_pred,  
    score_threshold=0.8  
)
